# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as tfk
import tensorflow_datasets as tfds

tfkl = tfk.layers

# %% [markdown]
# ### MNIST data
# Here is some code to load the MNIST digit recognition dataet and associated metadata

# %%
data, info = tfds.load('mnist', with_info=True)
print(info)
# Out:
# tfds.core.DatasetInfo(
#     name='mnist',
#     version=3.0.1,
#     description='The MNIST database of handwritten digits.',
#     homepage='http://yann.lecun.com/exdb/mnist/',
#     features=FeaturesDict({
#         'image': Image(shape=(28, 28, 1), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
#     }),
#     total_num_examples=70000,
#     splits={
#         'test': 10000,
#         'train': 60000,
#     },
#     supervised_keys=('image', 'label'),
#     citation="""@article{lecun2010mnist,
#       title={MNIST handwritten digit database},
#       author={LeCun, Yann and Cortes, Corinna and Burges, CJ},
#       journal={ATT Labs [Online]. Available: http://yann.lecun.com/exdb/mnist},
#       volume={2},
#       year={2010}
#     }""",
#     redistribution_info=,
# )

# %% [markdown]
# ### Preprocessing
#
# Let's start by writting a preprocessing function.
#
# TensorFlow Datasets packages the MNIST data such that each element is a `dict` with two keys:
# - `image`: an array containing the image with shape (28, 28, 1), values of type `uint8`, and values between 0 and 255
# - `label`: An integer between 0 - 9 indicating the digit in the image
#
# Write a `preprocess` function that takes in one such element and prepares it for training an autoencoder. Things to make sure your function does:
# 1. Cast the image to a `float32`
# 2. Scale the values of the images so they are between 0 - 1
# 3. Return a tuple with the transformed image and the label
#
# Then write another function called `ae_targets` that transforms this $(x, y)$ pair into the tuple that represents the input and target that are appropriate for an autoencoder.
#
# Finally, transform the originally dataset with the following steps:
# 1. Grab the training dataset
# 2. apply (i.e. "map") the preprocessing function
# 3. apply the function to generate appropriate autoencoder targets
# 3. cache the results (so you only to these tranformations the first time through the dataset)
# 4. split the dataset into batches of size `32`
# 5. set up the resulting dataset to repeat
# 6. set up the resulting dataset to prefetch `5` elements
#
# (there is a chain of functions on the `Dataset` to do each of these!)

# %%
# your code here
preprocess = lambda d: (tf.cast(d['image'],tf.float32)/255.,d['label'])
ae_targets = lambda x,y:(x,x)

ds_train = data['train'].map(preprocess).map(lambda x, y:(x,x)).cache().batch(32).repeat().prefetch(5)

# %% [markdown]
# ### TensorFlow function API + a simple autoencoder
#
# We will want to use the encoder and decoder from our autoencoder separately down the road. Here is some code to build a simple autoencoder with a single hidden layer using the TensorFlow 'functional API' to see show we can combine two submodels (in this case the encoder and the decoder) into on larger model.

# %%
img_shape = info.features['image'].shape
print(img_shape)
print(np.prod(img_shape))
# Out:
# (28, 28, 1)
# 784

# %%
encoder = tfk.Sequential([
  tfkl.InputLayer(img_shape),
  tfkl.Flatten(),
  tfkl.Dense(32, activation=tf.nn.relu)
])
encoder.summary()

decoder = tfk.Sequential([
  tfkl.InputLayer(32),
  tfkl.Dense(np.prod(img_shape), activation=tf.nn.sigmoid),
  tfkl.Reshape(img_shape)
])
decoder.summary()

# the tf.keras function API starts with defining placeholder tensors that represent model inputs
x = tfkl.Input(img_shape)

# we can then pass this placeholder through our models to specify the computation to get a prediction
h = encoder(x)
xhat = decoder(h)

# finally we use the tfk.Model class instantiate the model by specifying the inputs and outputs
# (note: this can also be lists, which is how you make more complex models with multiple inputs and/or outputs)
autoencoder = tfk.Model(inputs=x, outputs=xhat)
autoencoder.summary()

# training happens as usual
autoencoder.compile(
    optimizer=tfk.optimizers.Adam(),
    loss=tfk.losses.BinaryCrossentropy(),
)

results = autoencoder.fit(ds_train, steps_per_epoch=400, epochs=20)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)
# Epoch 10/20
# 400/400 [==============================] - ETA: 1s - loss: 0.100 - ETA: 0s - loss: 0.099 - ETA: 0s - loss: 0.098 - ETA: 0s - loss: 0.099 - ETA: 0s - loss: 0.099 - ETA: 0s - loss: 0.099 - ETA: 0s - loss: 0.099 - ETA: 0s - loss: 0.098 - ETA: 0s - loss: 0.098 - ETA: 0s - loss: 0.098 - ETA: 0s - loss: 0.098 - ETA: 0s - loss: 0.098 - ETA: 0s - loss: 0.098 - ETA: 0s - loss: 0.098 - ETA: 0s - loss: 0.098 - ETA: 0s - loss: 0.098 - ETA: 0s - loss: 0.098 - ETA: 0s - loss: 0.098 - 1s 2ms/step - loss: 0.0985
# Epoch 11/20
# 400/400 [==============================] - ETA: 1s - loss: 0.099 - ETA: 0s - loss: 0.099 - ETA: 0s - loss: 0.097 - ETA: 0s - loss: 0.097 - ETA: 0s - loss: 0.097 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - 1s 2ms/step - loss: 0.0966
# Epoch 12/20
# 400/400 [==============================] - ETA: 1s - loss: 0.095 - ETA: 1s - loss: 0.098 - ETA: 0s - loss: 0.097 - ETA: 0s - loss: 0.097 - ETA: 0s - loss: 0.097 - ETA: 0s - loss: 0.097 - ETA: 0s - loss: 0.097 - ETA: 0s - loss: 0.097 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - 1s 2ms/step - loss: 0.0965
# Epoch 13/20
# 400/400 [==============================] - ETA: 1s - loss: 0.102 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.096 - 1s 2ms/step - loss: 0.0962
# Epoch 14/20
# 400/400 [==============================] - ETA: 1s - loss: 0.099 - ETA: 0s - loss: 0.096 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - 1s 2ms/step - loss: 0.0958
# Epoch 15/20
# 400/400 [==============================] - ETA: 2s - loss: 0.092 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - 1s 2ms/step - loss: 0.0954
# Epoch 16/20
# 400/400 [==============================] - ETA: 1s - loss: 0.093 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - 1s 2ms/step - loss: 0.0951
# Epoch 17/20
# 400/400 [==============================] - ETA: 1s - loss: 0.092 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.093 - ETA: 0s - loss: 0.093 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - 1s 3ms/step - loss: 0.0948
# Epoch 18/20
# 400/400 [==============================] - ETA: 2s - loss: 0.096 - ETA: 0s - loss: 0.093 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - 1s 2ms/step - loss: 0.0952
# Epoch 19/20
# 400/400 [==============================] - ETA: 1s - loss: 0.093 - ETA: 0s - loss: 0.093 - ETA: 0s - loss: 0.093 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.095 - 1s 2ms/step - loss: 0.0950
# Epoch 20/20
# 400/400 [==============================] - ETA: 1s - loss: 0.097 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.095 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - ETA: 0s - loss: 0.094 - 1s 2ms/step - loss: 0.0942

# %%
imgs = next(iter(ds_train))[0]
for i in range(10):
    plt.subplot(1, 2, 1)
    plt.imshow(imgs[i].numpy().squeeze(), cmap='bone')
    plt.subplot(1, 2, 2, )
    plt.imshow(autoencoder(imgs[i][tf.newaxis]).numpy().squeeze(), cmap='bone')
    plt.show()

# %% [markdown]
# ### Deep autoencoder and latent representations
#
# We want to reduce the dimensionality to the hidden layer so that we can plot the hidden representations to see how the autoencoder is organizing the data. If our hidden layers is going to be so much smaller, we will need to make up for it by making the network deeper.
#
# Modify the code above to make this work. Try a layers of size 156 -> 32 -> 2. After trining the model, use the encoder by itself and make a scatter plot of the some of the data, coloring each point by the digit identity. Which digits end up bunched together? Which are more well separated? Why might this be?

# %%
# your code here
encoder = tfk.Sequential([
  tfkl.InputLayer(img_shape),
  tfkl.Flatten(),
  tfkl.Dense(156, activation=tf.nn.relu),
  tfkl.Dense(32, activation=tf.nn.relu),
  tfkl.Dense(2, activation=None)
])
encoder.summary()

decoder = tfk.Sequential([
  tfkl.InputLayer(2),
  tfkl.Dense(32, activation=tf.nn.relu),
  tfkl.Dense(156, activation=tf.nn.relu),
  tfkl.Dense(np.prod(img_shape), activation=tf.nn.sigmoid),
  tfkl.Reshape(img_shape)
])
decoder.summary()

# the tf.keras function API starts with defining placeholder tensors that represent model inputs
x = tfkl.Input(img_shape)

# we can then pass this placeholder through our models to specify the computation to get a prediction
h = encoder(x)
xhat = decoder(h)

# finally we use the tfk.Model class instantiate the model by specifying the inputs and outputs
# (note: this can also be lists, which is how you make more complex models with multiple inputs and/or outputs)
autoencoder = tfk.Model(inputs=x, outputs=xhat)
autoencoder.summary()

# training happens as usual
autoencoder.compile(
    optimizer=tfk.optimizers.Adam(),
    loss=tfk.losses.BinaryCrossentropy(),
)

results = autoencoder.fit(ds_train, steps_per_epoch=400, epochs=20)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 156)               122460
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                5024
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 127,550
# Trainable params: 127,550
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 32)                96
# _________________________________________________________________
# dense_6 (Dense)              (None, 156)               5148
# _________________________________________________________________
# dense_7 (Dense)              (None, 784)               123088
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 28, 28, 1)         0
# =================================================================
# Total params: 128,332
# Trainable params: 128,332
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 2)                 127550
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 28, 28, 1)         128332
# =================================================================
# Total params: 255,882
# Trainable params: 255,882
# Non-trainable params: 0
# _________________________________________________________________
# Train for 400 steps
# Epoch 1/20
# 400/400 [==============================] - ETA: 2:59 - loss: 0.693 - ETA: 13s - loss: 0.609 - ETA: 7s - loss: 0.4664 - ETA: 4s - loss: 0.402 - ETA: 3s - loss: 0.370 - ETA: 3s - loss: 0.352 - ETA: 2s - loss: 0.337 - ETA: 2s - loss: 0.325 - ETA: 2s - loss: 0.320 - ETA: 2s - loss: 0.312 - ETA: 1s - loss: 0.307 - ETA: 1s - loss: 0.301 - ETA: 1s - loss: 0.296 - ETA: 1s - loss: 0.291 - ETA: 1s - loss: 0.288 - ETA: 1s - loss: 0.285 - ETA: 1s - loss: 0.283 - ETA: 1s - loss: 0.280 - ETA: 0s - loss: 0.278 - ETA: 0s - loss: 0.276 - ETA: 0s - loss: 0.275 - ETA: 0s - loss: 0.273 - ETA: 0s - loss: 0.271 - ETA: 0s - loss: 0.270 - ETA: 0s - loss: 0.269 - ETA: 0s - loss: 0.267 - ETA: 0s - loss: 0.265 - ETA: 0s - loss: 0.264 - ETA: 0s - loss: 0.263 - ETA: 0s - loss: 0.262 - ETA: 0s - loss: 0.261 - ETA: 0s - loss: 0.260 - 2s 5ms/step - loss: 0.2597
# Epoch 2/20
- ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - 1s 3ms/step - loss: 0.1888
# Epoch 15/20
# 400/400 [==============================] - ETA: 1s - loss: 0.185 - ETA: 1s - loss: 0.189 - ETA: 1s - loss: 0.185 - ETA: 1s - loss: 0.184 - ETA: 1s - loss: 0.187 - ETA: 1s - loss: 0.187 - ETA: 1s - loss: 0.188 - ETA: 1s - loss: 0.187 - ETA: 1s - loss: 0.188 - ETA: 1s - loss: 0.188 - ETA: 1s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - ETA: 0s - loss: 0.188 - 1s 4ms/step - loss: 0.1884
# Epoch 16/20
# 400/400 [==============================] - ETA: 1s - loss: 0.178 - ETA: 1s - loss: 0.181 - ETA: 1s - loss: 0.187 - ETA: 1s - loss: 0.185 - ETA: 1s - loss: 0.185 - ETA: 1s - loss: 0.186 - ETA: 1s - loss: 0.187 - ETA: 1s - loss: 0.187 - ETA: 1s - loss: 0.186 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.187 - 1s 3ms/step - loss: 0.1872
# Epoch 17/20
# 400/400 [==============================] - ETA: 1s - loss: 0.179 - ETA: 1s - loss: 0.189 - ETA: 1s - loss: 0.188 - ETA: 1s - loss: 0.188 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.187 - ETA: 0s - loss: 0.187 - ETA: 0s - loss: 0.187 - 1s 3ms/step - loss: 0.1869
# Epoch 18/20
# 400/400 [==============================] - ETA: 2s - loss: 0.178 - ETA: 1s - loss: 0.182 - ETA: 1s - loss: 0.185 - ETA: 1s - loss: 0.184 - ETA: 1s - loss: 0.185 - ETA: 1s - loss: 0.185 - ETA: 1s - loss: 0.186 - ETA: 1s - loss: 0.186 - ETA: 1s - loss: 0.186 - ETA: 1s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - 1s 4ms/step - loss: 0.1863
# Epoch 19/20
# 400/400 [==============================] - ETA: 1s - loss: 0.175 - ETA: 1s - loss: 0.181 - ETA: 1s - loss: 0.183 - ETA: 1s - loss: 0.183 - ETA: 1s - loss: 0.184 - ETA: 0s - loss: 0.184 - ETA: 0s - loss: 0.184 - ETA: 0s - loss: 0.184 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - 1s 3ms/step - loss: 0.1857
# Epoch 20/20
# 400/400 [==============================] - ETA: 1s - loss: 0.185 - ETA: 1s - loss: 0.188 - ETA: 1s - loss: 0.187 - ETA: 1s - loss: 0.185 - ETA: 1s - loss: 0.185 - ETA: 1s - loss: 0.183 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.186 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.184 - ETA: 0s - loss: 0.184 - ETA: 0s - loss: 0.185 - ETA: 0s - loss: 0.184 - ETA: 0s - loss: 0.184 - 1s 3ms/step - loss: 0.1844

# %%
for i in range(10):
    plt.subplot(1, 2, 1)
    plt.imshow(imgs[i].numpy().squeeze(), cmap='bone')
    plt.subplot(1, 2, 2, )
    plt.imshow(autoencoder(imgs[i][tf.newaxis]).numpy().squeeze(), cmap='bone')
    plt.show()

# %%
# get 1000 data points for the scatter plot
x, y = next(iter(data['test'].map(preprocess).batch(1000)))

# %%
# your code here -- run the data through the encoder and scatter plot the results
h = encoder(x).numpy()

# %%
plt.figure(figsize=(7,7))
for i in range(10):
    inds = np.where(y == i)[0]
    plt.scatter(h[inds,0],h[inds,1],s=10,label=str(i))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
